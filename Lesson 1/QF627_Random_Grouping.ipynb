# %% [markdown]
# # QF 627 Programming and Computational Finance
# ### Random Assignment for Group Problem-Solving Leadership

# %%
import random
import pandas as pd

# %%
roster = pd.read_csv("qf627_g3.csv")
roster
# Out:
#                                 name
# 0                 JUNE YAP CHOU YENG
# 1              PANG JIUN SHYAN NIGEL
# 2               JEREMY LOW WEI LIANG
# 3                      TEAI JUIN WEN
# 4                          LIU YIRAN
# 5                   BRANDON SIM YANG
# 6               DILLON LOW CHUN KIAT
# 7                        JIANG SHUAI
# 8                KEE ZEALIN JI ZELIN
# 9                           CAI YUYE
# 10                     WAI JIAN RONG
# 11                      KOH SHI LING
# 12           CLIFTON HOONG TIK SHANG
# 13               IVAN CHIN CHENG XIN
# 14                       LEW GAO WEI
# 15          TAN SI YIN JODIE ETHELDA
# 16               GABRIEL TAN JUN JIE
# 17               ADHI NARAYAN THARUN
# 18                  Y KARTHIKESWARAN
# 19                        LEE JIA YU
# 20                   LYNN LIM SI JIE
# 21                    LEE HIAO HUANG
# 22              TERENCE TAN YONG WEN
# 23                        LIM DAOWEN
# ...

# %%
students = roster["name"].tolist()

# %%
random.seed(2025)

# %%
members_per_group = 5

# %%
group = 1

for s in students[:]:
    if members_per_group == 5:
        print("***** Group {} *****".format(group)
             ) 
        members_per_group = 0
        group += 1
    
    student = random.choice(students)
    
    print(student)
    
    members_per_group += 1
    
    students.remove(str(student)
                   )
# Out:
# ***** Group 1 *****
# RAYMON GABRIEL GOH WEN KWAN
# BRANDON SIM YANG
# ZHOU QIANYING
# MIKHAIL RIYAD MOHD RIDZUAN
# CLIFTON HOONG TIK SHANG
# ***** Group 2 *****
# TIAN AO
# JUNE YAP CHOU YENG
# JULIAN NICHOLAS CHANG ZHONG-YANG
# NG JUN HAO
# LOW YUAN TING
# ***** Group 3 *****
# ADHI NARAYAN THARUN
# DILLON LOW CHUN KIAT
# CHIU TSONG-PING
# YONG HAN CHUEN
# CAI YUYE
# ***** Group 4 *****
# TEAI JUIN WEN
# JIANG SHUAI
# YEO ENG WAY
# IVAN CHIN CHENG XIN
# LEE HIAO HUANG
# ***** Group 5 *****
# KEE ZEALIN JI ZELIN
# EDMUND HO GUANG WEI
# JEREMY LOW WEI LIANG
# CHAN WEI YANG
# PANG JIUN SHYAN NIGEL
# ***** Group 6 *****
# YOHANES ALFREDO PHOA
# XIE GUANGYU
# KOH SHI LING
# LEE JIA YU
# LYNN LIM SI JIE
# ***** Group 7 *****
# LIU YIRAN
# GOH ZHU DI
# SHOBHIT NARAYANAN
# JOSEPH KWEE JIA MING
# TEO JIAN JUN MORRIS
# ***** Group 8 *****
# LIM DAOWEN
# ADRIANUS CHRISTOPHER
# TERENCE TAN YONG WEN
# CHEN JUN
# WAI JIAN RONG
# ***** Group 9 *****
# FENG HAOLIN
# LEW GAO WEI
# TAN MEI LING
# ...

# %% [markdown]
# ### YAY~ I wish you the best for the problem-solving exercise, Team :)
